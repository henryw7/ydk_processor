# %%
from search_card import search_card_name

# %%
inexact_name = "livetwin"
possible_cards = search_card_name(inexact_name)
for card_name in possible_cards:
    print(card_name)
# Out:
# Live☆Twin Channel
# Live☆Twin Home
# Live☆Twin Ki-sikil
# Live☆Twin Ki-sikil Frost
# Live☆Twin Lil-la
# Live☆Twin Lil-la Sweet
# Live☆Twin Lil-la Treat
# Live☆Twin Sunny's Snitch
